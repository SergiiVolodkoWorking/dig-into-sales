# %%
import pandas as pd

deals_df = pd.read_csv('../data/all-deals.csv', index_col=0)

# %% [markdown]
# # What are the `Travel` companies?

# %%
travel_companies = deals_df[deals_df['Industry'].str.contains("Travel")==True]
travel_companies.head(30)
# Out:
#         Deal ID                                          Deal Name  \
# 6    1023704553  ZIM - Vessel Allocations Extension Lab Service...
# 58    262866686  Northstar Travel Group - Maintenance Support 2018
# 64    522115497                              NetTracer API Project
# 67    262787908                                       Via TRM (UK)
# 146   289884077                 Via TRM - UI Refresh w/React&Redux
# 177   320200853  Axus - GDPR Compliance and Website Infrastruct...
# 252   262779170                         AXUS Full time maintenance
# 281   262808459                              Carnival Cruise Lines
# 332   262866729                                 Google Site Search
# 341   262844470                                    Cloud Migration
# 371   262808454                                               Axus
# 381   262779452                                Feature Development
# 58    307114781  Northstar Travel Group, LLC - Autoscaling Project
# ...

# %%
df = travel_companies[['Deal Name', 'Associated Company', 'Industry']]
df.head(30)
# Out:
#                                              Deal Name  \
# 6    ZIM - Vessel Allocations Extension Lab Service...
# 58   Northstar Travel Group - Maintenance Support 2018
# 64                               NetTracer API Project
# 67                                        Via TRM (UK)
# 146                 Via TRM - UI Refresh w/React&Redux
# 177  Axus - GDPR Compliance and Website Infrastruct...
# 252                         AXUS Full time maintenance
# 281                              Carnival Cruise Lines
# 332                                 Google Site Search
# 341                                    Cloud Migration
# 371                                               Axus
# 381                                Feature Development
# 58   Northstar Travel Group, LLC - Autoscaling Project
# 183                     DayAxe, Inc - CTO as a Service
# 276                            MVP for Travel Industry
# 367  Consultants for complex regulatory and leasing...
# ...

# %% [markdown]
# ## What are EO source companies?

# %% [markdown]
# ### EO is Paul's Network

# %%
eo_companies = deals_df[deals_df['Source']=="EO"]
eo_companies.head()
# Out:
#        Deal ID                           Deal Name       Deal owner  \
# 67   262787908                        Via TRM (UK)   Margaret Pagel
# 107  428843146  A Tavola - Support and Maintenance  Malcolm Newsome
# 171  262808597                                 IMO       Paul Pagel
#
#      Deal Stage      Sales Lead Designated Office         Director Industry  \
# 67            1  Margaret Pagel           Chicago  Malcolm Newsome   Travel
# 107           0      Paul Pagel           Chicago  Malcolm Newsome      NaN
# 171           0      Paul Pagel           Chicago              NaN      NaN
#
#     Source Associated Company ID Associated Company Associated Contact IDs  \
# 67      EO             677980896            Via TRM                    NaN
# 107     EO            1102718573           A Tavola                    NaN
# 171     EO             727202490                IMO                    NaN
#
#     Associated Contacts    Business Lines
# ...

# %% [markdown]
# # Source: None

# %%
travel_companies = deals_df[deals_df['Industry']=="Travel"]
travel_companies.head(200)
# Out:
#         Deal ID                                          Deal Name  \
# 6    1023704553  ZIM - Vessel Allocations Extension Lab Service...
# 58    262866686  Northstar Travel Group - Maintenance Support 2018
# 64    522115497                              NetTracer API Project
# 67    262787908                                       Via TRM (UK)
# 146   289884077                 Via TRM - UI Refresh w/React&Redux
# 177   320200853  Axus - GDPR Compliance and Website Infrastruct...
# 252   262779170                         AXUS Full time maintenance
# 281   262808459                              Carnival Cruise Lines
# 332   262866729                                 Google Site Search
# 341   262844470                                    Cloud Migration
# 371   262808454                                               Axus
# 381   262779452                                Feature Development
# 58    307114781  Northstar Travel Group, LLC - Autoscaling Project
# ...

# %%
non_sourced = deals_df[deals_df['Source']=="None"]
non_sourced.head()
# Out:
#         Deal ID                          Deal Name       Deal owner  \
# 0    1126055965  American Family Insurance - Shark   Kevin Kotowski
# 232   262866617              Managed Services Team  Malcolm Newsome
# 47    436851031       ActiveCampaign - Weirich (2)      Ryan Verner
#
#      Deal Stage    Sales Lead Designated Office         Director   Industry  \
# 0             1  Dennis Moore           Madison   Kevin Kotowski  Insurance
# 232           1    Paul Pagel           Chicago  Malcolm Newsome        NaN
# 47            0   Ryan Verner           Chicago      Ryan Verner        NaN
#
#     Source Associated Company ID         Associated Company  \
# 0     None             846172243  American Family Insurance
# 232   None                   NaN                        NaN
# 47    None             759528150             ActiveCampaign
#
#     Associated Contact IDs Associated Contacts Business Lines
# 0                      NaN                 NaN            NaN
# ...

# %%
non_sourced = deals_df[deals_df['Source'].isnull()]
non_sourced.head()
# Out:
#       Deal ID                                          Deal Name  \
# 57  262866640  Pro Bono apprenticeship project - Youth Employ...
# 63  314470409                          oryxsystems.com - Ongoing
# 65  258722004                        TWiG, LLC - iOS App Project
# 68  258492703                           Project Travel - Via TRM
# 71  258733639      ConceiveAbilities - Marketing Website Rebuild
#
#                        Deal owner  Deal Stage      Sales Lead  \
# 57                 Margaret Pagel           1  Margaret Pagel
# 63  Jim Remsik (Deactivated User)           1    Dennis Moore
# 65                  Jordan Koczot           1             NaN
# 68                  Jordan Koczot           1             NaN
# 71                Malcolm Newsome           1    Dennis Moore
#
#    Designated Office                       Director    Industry Source  \
# 57       Los Angeles                     Dave Moore  Government    NaN
# ...

# %%
no_industry = deals_df[~deals_df['Industry'].isnull()]
no_industry.head(1200)
# Out:
#         Deal ID                                          Deal Name  \
# 0    1126055965                  American Family Insurance - Shark
# 1     362032710                                                SSE
# 2     941965426                              Confluency - X Factor
# 3     905986805  Reverb - Holistic On-boarding/Training/Mentor ...
# 6    1023704553  ZIM - Vessel Allocations Extension Lab Service...
# ..          ...                                                ...
# 960   262729209     National Savings and Investments POC with ATOS
# 961   262729203                                   Save Development
# 962   262729197                           Members Engineering Team
# 982   262701339                            PrincessJewelry Website
# 995   262701286                                     Hockey Protege
#
#          Deal owner  Deal Stage      Sales Lead Designated Office  \
# 0    Kevin Kotowski           1    Dennis Moore           Madison
# ...
